# %%
# !pip install tokenizers
# !pip install torchtext
# !pip install pytorch_lightning
# !pip install datasets
# !pip install tensorboard
# Out:
# Requirement already satisfied: tokenizers in /opt/conda/envs/pytorch/lib/python3.10/site-packages (0.19.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from tokenizers) (0.23.3)
# Requirement already satisfied: filelock in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers) (3.14.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers) (2024.3.1)
# Requirement already satisfied: packaging>=20.9 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers) (21.3)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers) (6.0.1)
# Requirement already satisfied: requests in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers) (4.66.4)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers) (4.12.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from packaging>=20.9->huggingface-hub<1.0,>=0.16.4->tokenizers) (3.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from requests->huggingface-hub<1.0,>=0.16.4->tokenizers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from requests->huggingface-hub<1.0,>=0.16.4->tokenizers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from requests->huggingface-hub<1.0,>=0.16.4->tokenizers) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from requests->huggingface-hub<1.0,>=0.16.4->tokenizers) (2024.2.2)
# Requirement already satisfied: torchtext in /opt/conda/envs/pytorch/lib/python3.10/site-packages (0.17.0)
# Requirement already satisfied: tqdm in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from torchtext) (4.66.4)
# Requirement already satisfied: requests in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from torchtext) (2.32.3)
# Requirement already satisfied: torch in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from torchtext) (2.2.0)
# Requirement already satisfied: numpy in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from torchtext) (1.26.4)
# Requirement already satisfied: torchdata in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from torchtext) (0.7.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from requests->torchtext) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from requests->torchtext) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from requests->torchtext) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from requests->torchtext) (2024.2.2)
# Requirement already satisfied: filelock in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from torch->torchtext) (3.14.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from torch->torchtext) (4.12.1)
# Requirement already satisfied: sympy in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from torch->torchtext) (1.12)
# Requirement already satisfied: networkx in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from torch->torchtext) (3.3)
# Requirement already satisfied: jinja2 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from torch->torchtext) (3.1.4)
# Requirement already satisfied: fsspec in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from torch->torchtext) (2024.3.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from jinja2->torch->torchtext) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from sympy->torch->torchtext) (1.3.0)
# Requirement already satisfied: pytorch_lightning in /opt/conda/envs/pytorch/lib/python3.10/site-packages (2.2.5)
# Requirement already satisfied: numpy>=1.17.2 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from pytorch_lightning) (1.26.4)
# Requirement already satisfied: torch>=1.13.0 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from pytorch_lightning) (2.2.0)
# Requirement already satisfied: tqdm>=4.57.0 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from pytorch_lightning) (4.66.4)
# Requirement already satisfied: PyYAML>=5.4 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from pytorch_lightning) (6.0.1)
# Requirement already satisfied: fsspec>=2022.5.0 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from fsspec[http]>=2022.5.0->pytorch_lightning) (2024.3.1)
# Requirement already satisfied: torchmetrics>=0.7.0 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from pytorch_lightning) (1.4.0.post0)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from pytorch_lightning) (21.3)
# Requirement already satisfied: typing-extensions>=4.4.0 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from pytorch_lightning) (4.12.1)
# Requirement already satisfied: lightning-utilities>=0.8.0 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from pytorch_lightning) (0.11.2)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from fsspec[http]>=2022.5.0->pytorch_lightning) (3.9.5)
# Requirement already satisfied: setuptools in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from lightning-utilities>=0.8.0->pytorch_lightning) (69.5.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from packaging>=20.0->pytorch_lightning) (3.1.2)
# Requirement already satisfied: filelock in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from torch>=1.13.0->pytorch_lightning) (3.14.0)
# Requirement already satisfied: sympy in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from torch>=1.13.0->pytorch_lightning) (1.12)
# Requirement already satisfied: networkx in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from torch>=1.13.0->pytorch_lightning) (3.3)
# Requirement already satisfied: jinja2 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from torch>=1.13.0->pytorch_lightning) (3.1.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (4.0.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from jinja2->torch>=1.13.0->pytorch_lightning) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from sympy->torch>=1.13.0->pytorch_lightning) (1.3.0)
# Requirement already satisfied: idna>=2.0 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from yarl<2.0,>=1.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (3.7)
# Requirement already satisfied: datasets in /opt/conda/envs/pytorch/lib/python3.10/site-packages (2.19.2)
# Requirement already satisfied: filelock in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from datasets) (3.14.0)
# Requirement already satisfied: numpy>=1.17 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from datasets) (1.26.4)
# Requirement already satisfied: pyarrow>=12.0.0 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from datasets) (16.1.0)
# Requirement already satisfied: pyarrow-hotfix in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from datasets) (0.6)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.1 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.62.1 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from datasets) (4.66.4)
# Requirement already satisfied: xxhash in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from datasets) (3.4.1)
# Requirement already satisfied: multiprocess in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2024.3.1,>=2023.1.0 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from fsspec[http]<=2024.3.1,>=2023.1.0->datasets) (2024.3.1)
# Requirement already satisfied: aiohttp in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from datasets) (3.9.5)
# Requirement already satisfied: huggingface-hub>=0.21.2 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from datasets) (0.23.3)
# Requirement already satisfied: packaging in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from datasets) (21.3)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from datasets) (6.0.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from aiohttp->datasets) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from aiohttp->datasets) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from aiohttp->datasets) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from huggingface-hub>=0.21.2->datasets) (4.12.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from packaging->datasets) (3.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from requests>=2.32.1->datasets) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from requests>=2.32.1->datasets) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from requests>=2.32.1->datasets) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from requests>=2.32.1->datasets) (2024.2.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from pandas->datasets) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: six>=1.5 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Requirement already satisfied: tensorboard in /opt/conda/envs/pytorch/lib/python3.10/site-packages (2.17.0)
# Requirement already satisfied: absl-py>=0.4 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from tensorboard) (2.1.0)
# Requirement already satisfied: grpcio>=1.48.2 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from tensorboard) (1.64.1)
# Requirement already satisfied: markdown>=2.6.8 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from tensorboard) (3.6)
# Requirement already satisfied: numpy>=1.12.0 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from tensorboard) (1.26.4)
# Requirement already satisfied: protobuf!=4.24.0,<5.0.0,>=3.19.6 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from tensorboard) (4.25.3)
# Requirement already satisfied: setuptools>=41.0.0 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from tensorboard) (69.5.1)
# Requirement already satisfied: six>1.9 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from tensorboard) (1.16.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from tensorboard) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from tensorboard) (3.0.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard) (2.1.5)

# %%
from config_file import get_config
from train import train_model

config = get_config()
config["batch_size"] = 16
config["preload"] = None
config["num_epochs"] = 30
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
train_model(config)
# Out:
# Using device : cuda
# Downloading readme:   0%|          | 0.00/28.1k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/5.73M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/32332 [00:00<?, ? examples/s]
# Max length of the source sentence : 309
# Max length of the source target : 274
# 0
# Processing Epoch 00: 100%|██████████| 1819/1819 [21:52<00:00,  1.39it/s, loss=6.123]
# 1
# Processing Epoch 01: 100%|██████████| 1819/1819 [21:32<00:00,  1.41it/s, loss=5.637]
# 2
# Processing Epoch 02: 100%|██████████| 1819/1819 [21:32<00:00,  1.41it/s, loss=5.412]
# 3
# Processing Epoch 03: 100%|██████████| 1819/1819 [21:33<00:00,  1.41it/s, loss=4.824]
# 4
# Processing Epoch 04: 100%|██████████| 1819/1819 [21:33<00:00,  1.41it/s, loss=4.663]
# 5
# Processing Epoch 05: 100%|██████████| 1819/1819 [21:32<00:00,  1.41it/s, loss=4.579]
# 6
# Processing Epoch 06: 100%|██████████| 1819/1819 [21:32<00:00,  1.41it/s, loss=4.398]
# 7
# Processing Epoch 07: 100%|██████████| 1819/1819 [21:32<00:00,  1.41it/s, loss=3.902]
# 8
# Processing Epoch 08: 100%|██████████| 1819/1819 [21:32<00:00,  1.41it/s, loss=3.821]
# 9
# Processing Epoch 09: 100%|██████████| 1819/1819 [21:32<00:00,  1.41it/s, loss=3.545]
# 10
# Processing Epoch 10: 100%|██████████| 1819/1819 [21:32<00:00,  1.41it/s, loss=3.151]
# 11
# Processing Epoch 11: 100%|██████████| 1819/1819 [21:32<00:00,  1.41it/s, loss=3.558]
# 12
# Processing Epoch 12: 100%|██████████| 1819/1819 [21:32<00:00,  1.41it/s, loss=2.913]
# 13
# Processing Epoch 13: 100%|██████████| 1819/1819 [21:32<00:00,  1.41it/s, loss=2.717]
# 14
# Processing Epoch 14:   1%|          | 19/1819 [00:13<21:20,  1.41it/s, loss=2.671]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 train_model(config)
#
# File ~/erav2/S16/S16_code/train.py:212, in train_model(config)
#     209 batch_iterator = tqdm(train_dataloader, desc = f"Processing Epoch {epoch:02d}")
#     211 for batch in batch_iterator:
# --> 212     encoder_input = batch["encoder_input"].to(device)
#     213     decoder_input = batch["decoder_input"].to(device)
#     214     encoder_mask = batch["encoder_mask"].to(device)
#
# KeyboardInterrupt:
